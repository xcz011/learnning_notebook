# %%
from PIL import Image
import os, sys

# %%
# Read the image
im = Image.open('images/chapter1_cat_example.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=197x250 at 0x10F8F71D0>

# %%
print(im.format, im.size, im.mode)
# Out:
# JPEG (197, 250) RGB

# %%
# Save the images
im.save('cat.png')

# %%
# Copy a subrectangele from image
box = (100, 100, 150, 150)
region = im.crop(box)
region
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x10F8FEAD0>

# %%
# Processing a subrectangle, and pasting it back
region = region.transpose(Image.ROTATE_180)
im.paste(region, box)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=197x250 at 0x10F8F71D0>

# %%
# Simple geometry transforms
im = Image.open('images/chapter1_cat_example.jpg')
out = im.resize((128, 128))
out = im.rotate(45) # degrees counter-clockwise
out
# Out:
# <PIL.Image.Image image mode=RGB size=197x250 at 0x10F27A4D0>

# %%
# Converting between modes
im = Image.open('images/chapter1_cat_example.jpg')
out = im.convert("L")
out
# Out:
# <PIL.Image.Image image mode=L size=197x250 at 0x10F27A990>

# %%
# apply filter
from PIL import ImageFilter
out = im.filter(ImageFilter.EDGE_ENHANCE_MORE)
out
# Out:
# <PIL.Image.Image image mode=RGB size=197x250 at 0x10E814890>

# %%
# Ehhancing Images
from PIL import ImageEnhance

enh = ImageEnhance.Contrast(im)
enh = enh.enhance(1.3)
enh
# Out:
# <PIL.Image.Image image mode=RGB size=197x250 at 0x10E815690>
